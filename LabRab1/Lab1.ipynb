# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
data=pd.read_csv('Fish.csv')
print(data)
# Out:
#      Species  Weight  Length1  Length2  Length3   Height   Width
# 0          1   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1          1   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2          1   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3          1   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4          1   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..       ...     ...      ...      ...      ...      ...     ...
# 154        7    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155        7    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156        7    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157        7    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158        7    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
data.isnull().values.any()
# Out:
# False

# %%
data.dtypes
# Out:
# Species      int64
# Weight     float64
# Length1    float64
# Length2    float64
# Length3    float64
# Height     float64
# Width      float64
# dtype: object

# %%
data_disc = pd.read_csv('Fish.csv')
del[data_disc['Species']]
data_disc.describe()
# Out:
#             Weight     Length1     Length2     Length3      Height       Width
# count   159.000000  159.000000  159.000000  159.000000  159.000000  159.000000
# mean    398.326415   26.247170   28.415723   31.227044    8.970994    4.417486
# std     357.978317    9.996441   10.716328   11.610246    4.286208    1.685804
# min       0.000000    7.500000    8.400000    8.800000    1.728400    1.047600
# 25%     120.000000   19.050000   21.000000   23.150000    5.944800    3.385650
# 50%     273.000000   25.200000   27.300000   29.400000    7.786000    4.248500
# 75%     650.000000   32.700000   35.500000   39.650000   12.365900    5.584500
# max    1650.000000   59.000000   63.400000   68.000000   18.957000    8.142000

# %%
data_alt = data.sort_values('Weight')

m = [ ]
for i in range(159):
    m.append(i)   

plt.scatter(m, data_alt['Length3'])

# %%
data_alt = data.sort_values('Length3')

m = [ ]
for i in range(159):
        m.append(i)


plt.scatter(m, data_alt['Width'])

# %%
data_alt = data.sort_values('Weight')

m = [ ]
for i in range(159):
        m.append(i)
        
plt.scatter(m, data_alt['Width'])

# %%
plt.figure(figsize=(10, 2))
plt.subplot (1, 4, 1)
data['Weight'].hist()
plt.subplot (1, 4, 2)
data['Length3'].hist()
plt.subplot (1, 4, 3)
data['Height'].hist()
plt.subplot (1, 4, 4)
data['Width'].hist()
# Out:
# <AxesSubplot:>

# %%
del[data['Weight']]
boxplot = data.boxplot()

# %%
scaler = StandardScaler()
data_=pd.DataFrame(scaler.fit_transform(data))
boxplot = data_.boxplot()

# %%
delete = data['Length1'].quantile(0.95)
data = data.drop(data[data.Length1 >= delete].index)

delete = data['Length2'].quantile(0.95)
data = data.drop(data[data.Length2 >= delete].index)

delete = data['Length3'].quantile(0.95)
data = data.drop(data[data.Length3 >= delete].index)

scaler = StandardScaler()
data_=pd.DataFrame(scaler.fit_transform(data))
boxplot = data_.boxplot()

# %%
del[data_alt['Length1']]
del[data_alt['Length2']]
del[data_alt['Weight']]
sns.pairplot(data_alt,hue='Species')
